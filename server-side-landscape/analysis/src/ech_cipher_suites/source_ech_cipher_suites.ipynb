# %% [markdown]
# # Count offered ECH Cipher Suites

# %%
import os
import pickle
from datetime import datetime

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.pool import QueuePool

# Set pandas to display all rows and columns
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", 1000)  # Set a larger width for better view if necessary
pd.set_option("display.max_colwidth", None)  # Show full content of each column


# Load environment variables from .env file
load_dotenv("../.env")  # Adjust the path if your .env file is in a different location

testDates = [
    "2024-08-08",
    "2024-08-19",
    "2024-08-21",
    "2024-08-29",
    "2024-09-05",
    "2024-09-06",
    "2024-09-08",
    "2024-09-11",
    "2024-09-15",
    "2024-10-13",
    "2024-10-20",
    "2024-10-29",
    "2024-10-31",
    "2024-11-07",
    "2024-11-12",
    "2024-11-15",
    "2024-11-17",
    "2024-11-18",
    "2024-11-19",
    "2024-11-27",
    "2024-11-28",
    "2024-11-29",
    "2024-11-30",
    "2024-12-01",
    "2024-12-02",
    "2024-12-03",
    "2024-12-04",
    "2024-12-12",
    "2024-12-13",
    "2024-12-14",
    "2024-12-15",
    "2024-12-16",
    "2024-12-17",
    "2024-12-18",
    "2024-12-19",
    "2024-12-20",
    "2024-12-21",
    "2024-12-22",
    "2024-12-23",
    "2024-12-24",
    "2024-12-25",
    "2024-12-26",
    "2024-12-29",
    "2024-12-30",
    "2025-01-01",
    "2025-01-02",
    "2025-01-03",
    "2025-01-04",
    "2025-01-05",
    "2025-01-06",
    "2025-01-07",
    "2025-01-08",
    "2025-01-09",
    "2025-01-10",
    "2025-01-11",
    "2025-01-12",
    "2025-01-13",
    "2025-01-14",
    "2025-01-15",
    "2025-01-16",
    "2025-01-17",
    "2025-01-18",
    "2025-01-19",
    "2025-01-20",
    "2025-01-21",
    "2025-01-22",
    "2025-01-23",
    "2025-01-24",
    "2025-01-25",
    "2025-01-26",
    "2025-01-27",
    "2025-01-28",
    "2025-01-29",
    "2025-01-30",
    "2025-01-31",
    "2025-02-01",
    "2025-02-02",
    "2025-02-03",
    "2025-02-04",
    "2025-02-05",
    "2025-02-06",
    "2025-02-07",
    "2025-02-08",
    "2025-02-09",
    "2025-02-10",
    "2025-02-11",
    "2025-02-12",
    "2025-02-14",
    "2025-02-15",
    "2025-02-16",
    "2025-02-17",
    "2025-02-18",
    "2025-02-19",
]


def fetch_and_save_data(query, filename_suffix, params=None, timeout=3600):
    """
    Fetches data from PostgreSQL using SQLAlchemy with connection pooling,
    saves it to a pickle file, and handles timeouts.
    Reads database credentials from environment variables.

    Args:
        query (str): The SQL query to execute.
        filename_suffix (str): A string to be added to the pickle filename.
        params (tuple, optional): Parameters to pass to the query. Defaults to None.
        timeout (int, optional): The timeout for the database connection in seconds. Defaults to 3600.
    """
    try:
        db_user = os.getenv("DB_USER")
        db_password = os.getenv("DB_PASSWORD")
        db_host = os.getenv("DB_HOST")
        db_name = os.getenv("DB_NAME")

        engine = create_engine(
            f"postgresql+psycopg2://{db_user}:{db_password}@10.149.10.50/{db_name}",
            connect_args={"connect_timeout": timeout},
            poolclass=QueuePool,
            pool_size=5,
            max_overflow=10,
        )

        # Create an empty list to store the dataframes
        df_list = []

        with engine.connect() as conn:
            # Iterate over the testDates list
            for date in testDates:
                # Execute the query for each date
                params = (date,)
                df = pd.read_sql_query(query, conn, params=params)
                df_list.append(df)

        # Concatenate all the dataframes into a single dataframe
        final_df = pd.concat(df_list, ignore_index=True)

        print(final_df)
        os.makedirs("./pickle", exist_ok=True)
        filename = f"./pickle/{datetime.now().strftime('%Y-%m-%d_%HH-%MM-%SS')}_{filename_suffix}.pickle"

        with open(filename, "wb") as f:
            pickle.dump(final_df, f)

        print(f"Data saved to {filename}")

    except Exception as e:
        print(f"Error: {e}")


if __name__ == "__main__":
    query = """
SELECT
    ec.test_date,
    hcs.cipher_suite,
    COUNT(*) AS cipher_suite_count
FROM
    public."ECHCiphers" ec
JOIN
    public."HPKECipherSuites" hcs ON ec.ech_cipher_kdf_id = hcs.kdf_id AND ec.ech_cipher_aead_id = hcs.aead_id
WHERE
    ec.test_date = %s
    AND EXISTS (
        SELECT 1
        FROM public."HPKECipherSuites"
        WHERE kdf_id = ec.ech_cipher_kdf_id AND aead_id = ec.ech_cipher_aead_id
    )
GROUP BY
    ec.test_date, hcs.cipher_suite
ORDER BY
    ec.test_date, hcs.cipher_suite;
    """
    filename_suffix = "ech_cipher-suites_by_test_dates"
    fetch_and_save_data(query, filename_suffix)
# Out:
#       test_date                        cipher_suite  cipher_suite_count
# 0    2024-08-08        HKDF-SHA256 with AES-GCM-128                  30
# 1    2024-08-08  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 2    2024-08-19        HKDF-SHA256 with AES-GCM-128               15301
# 3    2024-08-19  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 4    2024-08-21        HKDF-SHA256 with AES-GCM-128               67979
# 5    2024-08-21  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 6    2024-08-29        HKDF-SHA256 with AES-GCM-128                  32
# 7    2024-08-29  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 8    2024-09-05        HKDF-SHA256 with AES-GCM-128              231499
# 9    2024-09-05        HKDF-SHA256 with AES-GCM-256                   1
# 10   2024-09-05  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 11   2024-09-05        HKDF-SHA384 with AES-GCM-128                   1
# 12   2024-09-05        HKDF-SHA384 with AES-GCM-256                   1
# 13   2024-09-05  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 14   2024-09-05        HKDF-SHA512 with AES-GCM-128                   1
# 15   2024-09-05        HKDF-SHA512 with AES-GCM-256                   1
# 16   2024-09-05  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 17   2024-09-06        HKDF-SHA256 with AES-GCM-128              455248
# 18   2024-09-06        HKDF-SHA256 with AES-GCM-256                   1
# 19   2024-09-06  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 20   2024-09-06        HKDF-SHA384 with AES-GCM-128                   1
# 21   2024-09-06        HKDF-SHA384 with AES-GCM-256                   1
# 22   2024-09-06  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 23   2024-09-06        HKDF-SHA512 with AES-GCM-128                   1
# 24   2024-09-06        HKDF-SHA512 with AES-GCM-256                   1
# 25   2024-09-06  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 26   2024-09-08        HKDF-SHA256 with AES-GCM-128              456616
# 27   2024-09-08        HKDF-SHA256 with AES-GCM-256                   1
# 28   2024-09-08  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 29   2024-09-08        HKDF-SHA384 with AES-GCM-128                   1
# 30   2024-09-08        HKDF-SHA384 with AES-GCM-256                   1
# 31   2024-09-08  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 32   2024-09-08        HKDF-SHA512 with AES-GCM-128                   1
# 33   2024-09-08        HKDF-SHA512 with AES-GCM-256                   1
# 34   2024-09-08  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 35   2024-09-11        HKDF-SHA256 with AES-GCM-128              705265
# 36   2024-09-11        HKDF-SHA256 with AES-GCM-256                   1
# 37   2024-09-11  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 38   2024-09-11        HKDF-SHA384 with AES-GCM-128                   1
# 39   2024-09-11        HKDF-SHA384 with AES-GCM-256                   1
# 40   2024-09-11  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 41   2024-09-11        HKDF-SHA512 with AES-GCM-128                   1
# 42   2024-09-11        HKDF-SHA512 with AES-GCM-256                   1
# 43   2024-09-11  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 44   2024-09-15        HKDF-SHA256 with AES-GCM-128              837497
# 45   2024-09-15        HKDF-SHA256 with AES-GCM-256                   1
# 46   2024-09-15  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 47   2024-09-15        HKDF-SHA384 with AES-GCM-128                   1
# 48   2024-09-15        HKDF-SHA384 with AES-GCM-256                   1
# 49   2024-09-15  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 50   2024-09-15        HKDF-SHA512 with AES-GCM-128                   1
# 51   2024-09-15        HKDF-SHA512 with AES-GCM-256                   1
# 52   2024-09-15  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 53   2024-10-13        HKDF-SHA256 with AES-GCM-128              831783
# 54   2024-10-13        HKDF-SHA256 with AES-GCM-256                   1
# 55   2024-10-13  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 56   2024-10-13        HKDF-SHA384 with AES-GCM-128                   1
# 57   2024-10-13        HKDF-SHA384 with AES-GCM-256                   1
# 58   2024-10-13  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 59   2024-10-13        HKDF-SHA512 with AES-GCM-128                   1
# 60   2024-10-13        HKDF-SHA512 with AES-GCM-256                   1
# 61   2024-10-13  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 62   2024-10-20        HKDF-SHA256 with AES-GCM-128             1163314
# 63   2024-10-20        HKDF-SHA256 with AES-GCM-256                   1
# 64   2024-10-20  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 65   2024-10-20        HKDF-SHA384 with AES-GCM-128                   1
# 66   2024-10-20        HKDF-SHA384 with AES-GCM-256                   1
# 67   2024-10-20  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 68   2024-10-20        HKDF-SHA512 with AES-GCM-128                   1
# 69   2024-10-20        HKDF-SHA512 with AES-GCM-256                   1
# 70   2024-10-20  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 71   2024-10-29        HKDF-SHA256 with AES-GCM-128              823100
# 72   2024-10-29        HKDF-SHA256 with AES-GCM-256                   1
# 73   2024-10-29  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 74   2024-10-29        HKDF-SHA384 with AES-GCM-128                   1
# 75   2024-10-29        HKDF-SHA384 with AES-GCM-256                   1
# 76   2024-10-29  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 77   2024-10-29        HKDF-SHA512 with AES-GCM-128                   1
# 78   2024-10-29        HKDF-SHA512 with AES-GCM-256                   1
# 79   2024-10-29  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 80   2024-10-31        HKDF-SHA256 with AES-GCM-128              825161
# 81   2024-10-31        HKDF-SHA256 with AES-GCM-256                   1
# 82   2024-10-31  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 83   2024-10-31        HKDF-SHA384 with AES-GCM-128                   1
# 84   2024-10-31        HKDF-SHA384 with AES-GCM-256                   1
# 85   2024-10-31  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 86   2024-10-31        HKDF-SHA512 with AES-GCM-128                   1
# 87   2024-10-31        HKDF-SHA512 with AES-GCM-256                   1
# 88   2024-10-31  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 89   2024-11-07        HKDF-SHA256 with AES-GCM-128             1141773
# 90   2024-11-07        HKDF-SHA256 with AES-GCM-256                   1
# 91   2024-11-07  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 92   2024-11-07        HKDF-SHA384 with AES-GCM-128                   1
# 93   2024-11-07        HKDF-SHA384 with AES-GCM-256                   1
# 94   2024-11-07  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 95   2024-11-07        HKDF-SHA512 with AES-GCM-128                   1
# 96   2024-11-07        HKDF-SHA512 with AES-GCM-256                   1
# 97   2024-11-07  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 98   2024-11-12        HKDF-SHA256 with AES-GCM-128             1131322
# 99   2024-11-12        HKDF-SHA256 with AES-GCM-256                   1
# 100  2024-11-12  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 101  2024-11-12        HKDF-SHA384 with AES-GCM-128                   1
# 102  2024-11-12        HKDF-SHA384 with AES-GCM-256                   1
# 103  2024-11-12  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 104  2024-11-12        HKDF-SHA512 with AES-GCM-128                   1
# 105  2024-11-12        HKDF-SHA512 with AES-GCM-256                   1
# 106  2024-11-12  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 107  2024-11-15        HKDF-SHA256 with AES-GCM-128             1135328
# 108  2024-11-15        HKDF-SHA256 with AES-GCM-256                   1
# 109  2024-11-15  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 110  2024-11-15        HKDF-SHA384 with AES-GCM-128                   1
# 111  2024-11-15        HKDF-SHA384 with AES-GCM-256                   1
# 112  2024-11-15  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 113  2024-11-15        HKDF-SHA512 with AES-GCM-128                   1
# 114  2024-11-15        HKDF-SHA512 with AES-GCM-256                   1
# 115  2024-11-15  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 116  2024-11-17        HKDF-SHA256 with AES-GCM-128             1128785
# 117  2024-11-17        HKDF-SHA256 with AES-GCM-256                   1
# 118  2024-11-17  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 119  2024-11-17        HKDF-SHA384 with AES-GCM-128                   1
# 120  2024-11-17        HKDF-SHA384 with AES-GCM-256                   1
# 121  2024-11-17  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 122  2024-11-17        HKDF-SHA512 with AES-GCM-128                   1
# 123  2024-11-17        HKDF-SHA512 with AES-GCM-256                   1
# 124  2024-11-17  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 125  2024-11-18        HKDF-SHA256 with AES-GCM-128             1128634
# 126  2024-11-18        HKDF-SHA256 with AES-GCM-256                   1
# 127  2024-11-18  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 128  2024-11-18        HKDF-SHA384 with AES-GCM-128                   1
# 129  2024-11-18        HKDF-SHA384 with AES-GCM-256                   1
# 130  2024-11-18  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 131  2024-11-18        HKDF-SHA512 with AES-GCM-128                   1
# 132  2024-11-18        HKDF-SHA512 with AES-GCM-256                   1
# 133  2024-11-18  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 134  2024-11-19        HKDF-SHA256 with AES-GCM-128             1127975
# 135  2024-11-19        HKDF-SHA256 with AES-GCM-256                   1
# 136  2024-11-19  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 137  2024-11-19        HKDF-SHA384 with AES-GCM-128                   1
# 138  2024-11-19        HKDF-SHA384 with AES-GCM-256                   1
# 139  2024-11-19  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 140  2024-11-19        HKDF-SHA512 with AES-GCM-128                   1
# 141  2024-11-19        HKDF-SHA512 with AES-GCM-256                   1
# 142  2024-11-19  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 143  2024-11-27        HKDF-SHA256 with AES-GCM-128             1125816
# 144  2024-11-27        HKDF-SHA256 with AES-GCM-256                   1
# 145  2024-11-27  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 146  2024-11-27        HKDF-SHA384 with AES-GCM-128                   1
# 147  2024-11-27        HKDF-SHA384 with AES-GCM-256                   1
# 148  2024-11-27  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 149  2024-11-27        HKDF-SHA512 with AES-GCM-128                   1
# 150  2024-11-27        HKDF-SHA512 with AES-GCM-256                   1
# 151  2024-11-27  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 152  2024-11-28        HKDF-SHA256 with AES-GCM-128             1124885
# 153  2024-11-28        HKDF-SHA256 with AES-GCM-256                   1
# 154  2024-11-28  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 155  2024-11-28        HKDF-SHA384 with AES-GCM-128                   1
# 156  2024-11-28        HKDF-SHA384 with AES-GCM-256                   1
# 157  2024-11-28  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 158  2024-11-28        HKDF-SHA512 with AES-GCM-128                   1
# 159  2024-11-28        HKDF-SHA512 with AES-GCM-256                   1
# 160  2024-11-28  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 161  2024-11-29        HKDF-SHA256 with AES-GCM-128             1123785
# 162  2024-11-29        HKDF-SHA256 with AES-GCM-256                   1
# 163  2024-11-29  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 164  2024-11-29        HKDF-SHA384 with AES-GCM-128                   1
# 165  2024-11-29        HKDF-SHA384 with AES-GCM-256                   1
# 166  2024-11-29  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 167  2024-11-29        HKDF-SHA512 with AES-GCM-128                   1
# 168  2024-11-29        HKDF-SHA512 with AES-GCM-256                   1
# 169  2024-11-29  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 170  2024-11-30        HKDF-SHA256 with AES-GCM-128             1123625
# 171  2024-11-30        HKDF-SHA256 with AES-GCM-256                   1
# 172  2024-11-30  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 173  2024-11-30        HKDF-SHA384 with AES-GCM-128                   1
# 174  2024-11-30        HKDF-SHA384 with AES-GCM-256                   1
# 175  2024-11-30  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 176  2024-11-30        HKDF-SHA512 with AES-GCM-128                   1
# 177  2024-11-30        HKDF-SHA512 with AES-GCM-256                   1
# 178  2024-11-30  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 179  2024-12-01        HKDF-SHA256 with AES-GCM-128             1123524
# 180  2024-12-01  HKDF-SHA256 with ChaCha20-Poly1305                   1
# 181  2024-12-02        HKDF-SHA256 with AES-GCM-128             1123027
# 182  2024-12-02        HKDF-SHA256 with AES-GCM-256                   1
# 183  2024-12-02  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 184  2024-12-02        HKDF-SHA384 with AES-GCM-128                   1
# 185  2024-12-02        HKDF-SHA384 with AES-GCM-256                   1
# 186  2024-12-02  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 187  2024-12-02        HKDF-SHA512 with AES-GCM-128                   1
# 188  2024-12-02        HKDF-SHA512 with AES-GCM-256                   1
# 189  2024-12-02  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 190  2024-12-03        HKDF-SHA256 with AES-GCM-128             1123102
# 191  2024-12-03        HKDF-SHA256 with AES-GCM-256                   1
# 192  2024-12-03  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 193  2024-12-03        HKDF-SHA384 with AES-GCM-128                   1
# 194  2024-12-03        HKDF-SHA384 with AES-GCM-256                   1
# 195  2024-12-03  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 196  2024-12-03        HKDF-SHA512 with AES-GCM-128                   1
# 197  2024-12-03        HKDF-SHA512 with AES-GCM-256                   1
# 198  2024-12-03  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 199  2024-12-04        HKDF-SHA256 with AES-GCM-128             1122920
# 200  2024-12-04        HKDF-SHA256 with AES-GCM-256                   1
# 201  2024-12-04  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 202  2024-12-04        HKDF-SHA384 with AES-GCM-128                   1
# 203  2024-12-04        HKDF-SHA384 with AES-GCM-256                   1
# 204  2024-12-04  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 205  2024-12-04        HKDF-SHA512 with AES-GCM-128                   1
# 206  2024-12-04        HKDF-SHA512 with AES-GCM-256                   1
# 207  2024-12-04  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 208  2024-12-12        HKDF-SHA256 with AES-GCM-128             1117228
# 209  2024-12-12        HKDF-SHA256 with AES-GCM-256                   1
# 210  2024-12-12  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 211  2024-12-12        HKDF-SHA384 with AES-GCM-128                   1
# 212  2024-12-12        HKDF-SHA384 with AES-GCM-256                   1
# 213  2024-12-12  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 214  2024-12-12        HKDF-SHA512 with AES-GCM-128                   1
# 215  2024-12-12        HKDF-SHA512 with AES-GCM-256                   1
# 216  2024-12-12  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 217  2024-12-13        HKDF-SHA256 with AES-GCM-128             1117371
# 218  2024-12-13        HKDF-SHA256 with AES-GCM-256                   1
# 219  2024-12-13  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 220  2024-12-13        HKDF-SHA384 with AES-GCM-128                   1
# 221  2024-12-13        HKDF-SHA384 with AES-GCM-256                   1
# 222  2024-12-13  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 223  2024-12-13        HKDF-SHA512 with AES-GCM-128                   1
# 224  2024-12-13        HKDF-SHA512 with AES-GCM-256                   1
# 225  2024-12-13  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 226  2024-12-14        HKDF-SHA256 with AES-GCM-128             1117112
# 227  2024-12-14        HKDF-SHA256 with AES-GCM-256                   1
# 228  2024-12-14  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 229  2024-12-14        HKDF-SHA384 with AES-GCM-128                   1
# 230  2024-12-14        HKDF-SHA384 with AES-GCM-256                   1
# 231  2024-12-14  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 232  2024-12-14        HKDF-SHA512 with AES-GCM-128                   1
# 233  2024-12-14        HKDF-SHA512 with AES-GCM-256                   1
# 234  2024-12-14  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 235  2024-12-15        HKDF-SHA256 with AES-GCM-128             1116602
# 236  2024-12-15        HKDF-SHA256 with AES-GCM-256                   1
# 237  2024-12-15  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 238  2024-12-15        HKDF-SHA384 with AES-GCM-128                   1
# 239  2024-12-15        HKDF-SHA384 with AES-GCM-256                   1
# 240  2024-12-15  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 241  2024-12-15        HKDF-SHA512 with AES-GCM-128                   1
# 242  2024-12-15        HKDF-SHA512 with AES-GCM-256                   1
# 243  2024-12-15  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 244  2024-12-16        HKDF-SHA256 with AES-GCM-128             1116654
# 245  2024-12-16        HKDF-SHA256 with AES-GCM-256                   1
# 246  2024-12-16  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 247  2024-12-16        HKDF-SHA384 with AES-GCM-128                   1
# 248  2024-12-16        HKDF-SHA384 with AES-GCM-256                   1
# 249  2024-12-16  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 250  2024-12-16        HKDF-SHA512 with AES-GCM-128                   1
# 251  2024-12-16        HKDF-SHA512 with AES-GCM-256                   1
# 252  2024-12-16  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 253  2024-12-17        HKDF-SHA256 with AES-GCM-128             1116792
# 254  2024-12-17        HKDF-SHA256 with AES-GCM-256                   1
# 255  2024-12-17  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 256  2024-12-17        HKDF-SHA384 with AES-GCM-128                   1
# 257  2024-12-17        HKDF-SHA384 with AES-GCM-256                   1
# 258  2024-12-17  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 259  2024-12-17        HKDF-SHA512 with AES-GCM-128                   1
# 260  2024-12-17        HKDF-SHA512 with AES-GCM-256                   1
# 261  2024-12-17  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 262  2024-12-18        HKDF-SHA256 with AES-GCM-128             1114904
# 263  2024-12-18        HKDF-SHA256 with AES-GCM-256                   1
# 264  2024-12-18  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 265  2024-12-18        HKDF-SHA384 with AES-GCM-128                   1
# 266  2024-12-18        HKDF-SHA384 with AES-GCM-256                   1
# 267  2024-12-18  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 268  2024-12-18        HKDF-SHA512 with AES-GCM-128                   1
# 269  2024-12-18        HKDF-SHA512 with AES-GCM-256                   1
# 270  2024-12-18  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 271  2024-12-19        HKDF-SHA256 with AES-GCM-128             1114981
# 272  2024-12-19        HKDF-SHA256 with AES-GCM-256                   1
# 273  2024-12-19  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 274  2024-12-19        HKDF-SHA384 with AES-GCM-128                   1
# 275  2024-12-19        HKDF-SHA384 with AES-GCM-256                   1
# 276  2024-12-19  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 277  2024-12-19        HKDF-SHA512 with AES-GCM-128                   1
# 278  2024-12-19        HKDF-SHA512 with AES-GCM-256                   1
# 279  2024-12-19  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 280  2024-12-20        HKDF-SHA256 with AES-GCM-128             1114990
# 281  2024-12-20        HKDF-SHA256 with AES-GCM-256                   1
# 282  2024-12-20  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 283  2024-12-20        HKDF-SHA384 with AES-GCM-128                   1
# 284  2024-12-20        HKDF-SHA384 with AES-GCM-256                   1
# 285  2024-12-20  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 286  2024-12-20        HKDF-SHA512 with AES-GCM-128                   1
# 287  2024-12-20        HKDF-SHA512 with AES-GCM-256                   1
# 288  2024-12-20  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 289  2024-12-21        HKDF-SHA256 with AES-GCM-128             1114838
# 290  2024-12-21        HKDF-SHA256 with AES-GCM-256                   1
# 291  2024-12-21  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 292  2024-12-21        HKDF-SHA384 with AES-GCM-128                   1
# 293  2024-12-21        HKDF-SHA384 with AES-GCM-256                   1
# 294  2024-12-21  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 295  2024-12-21        HKDF-SHA512 with AES-GCM-128                   1
# 296  2024-12-21        HKDF-SHA512 with AES-GCM-256                   1
# 297  2024-12-21  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 298  2024-12-22        HKDF-SHA256 with AES-GCM-128             1114465
# 299  2024-12-22        HKDF-SHA256 with AES-GCM-256                   1
# 300  2024-12-22  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 301  2024-12-22        HKDF-SHA384 with AES-GCM-128                   1
# 302  2024-12-22        HKDF-SHA384 with AES-GCM-256                   1
# 303  2024-12-22  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 304  2024-12-22        HKDF-SHA512 with AES-GCM-128                   1
# 305  2024-12-22        HKDF-SHA512 with AES-GCM-256                   1
# 306  2024-12-22  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 307  2024-12-23        HKDF-SHA256 with AES-GCM-128             1114783
# 308  2024-12-23        HKDF-SHA256 with AES-GCM-256                   1
# 309  2024-12-23  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 310  2024-12-23        HKDF-SHA384 with AES-GCM-128                   1
# 311  2024-12-23        HKDF-SHA384 with AES-GCM-256                   1
# 312  2024-12-23  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 313  2024-12-23        HKDF-SHA512 with AES-GCM-128                   1
# 314  2024-12-23        HKDF-SHA512 with AES-GCM-256                   1
# 315  2024-12-23  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 316  2024-12-24        HKDF-SHA256 with AES-GCM-128             1114836
# 317  2024-12-24        HKDF-SHA256 with AES-GCM-256                   1
# 318  2024-12-24  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 319  2024-12-24        HKDF-SHA384 with AES-GCM-128                   1
# 320  2024-12-24        HKDF-SHA384 with AES-GCM-256                   1
# 321  2024-12-24  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 322  2024-12-24        HKDF-SHA512 with AES-GCM-128                   1
# 323  2024-12-24        HKDF-SHA512 with AES-GCM-256                   1
# 324  2024-12-24  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 325  2024-12-25        HKDF-SHA256 with AES-GCM-128             1115023
# 326  2024-12-25        HKDF-SHA256 with AES-GCM-256                   1
# 327  2024-12-25  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 328  2024-12-25        HKDF-SHA384 with AES-GCM-128                   1
# 329  2024-12-25        HKDF-SHA384 with AES-GCM-256                   1
# 330  2024-12-25  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 331  2024-12-25        HKDF-SHA512 with AES-GCM-128                   1
# 332  2024-12-25        HKDF-SHA512 with AES-GCM-256                   1
# 333  2024-12-25  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 334  2024-12-26        HKDF-SHA256 with AES-GCM-128             1114910
# 335  2024-12-26        HKDF-SHA256 with AES-GCM-256                   1
# 336  2024-12-26  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 337  2024-12-26        HKDF-SHA384 with AES-GCM-128                   1
# 338  2024-12-26        HKDF-SHA384 with AES-GCM-256                   1
# 339  2024-12-26  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 340  2024-12-26        HKDF-SHA512 with AES-GCM-128                   1
# 341  2024-12-26        HKDF-SHA512 with AES-GCM-256                   1
# 342  2024-12-26  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 343  2024-12-29        HKDF-SHA256 with AES-GCM-128             1114870
# 344  2024-12-29        HKDF-SHA256 with AES-GCM-256                   1
# 345  2024-12-29  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 346  2024-12-29        HKDF-SHA384 with AES-GCM-128                   1
# 347  2024-12-29        HKDF-SHA384 with AES-GCM-256                   1
# 348  2024-12-29  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 349  2024-12-29        HKDF-SHA512 with AES-GCM-128                   1
# 350  2024-12-29        HKDF-SHA512 with AES-GCM-256                   1
# 351  2024-12-29  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 352  2024-12-30        HKDF-SHA256 with AES-GCM-128             1115109
# 353  2024-12-30        HKDF-SHA256 with AES-GCM-256                   1
# 354  2024-12-30  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 355  2024-12-30        HKDF-SHA384 with AES-GCM-128                   1
# 356  2024-12-30        HKDF-SHA384 with AES-GCM-256                   1
# 357  2024-12-30  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 358  2024-12-30        HKDF-SHA512 with AES-GCM-128                   1
# 359  2024-12-30        HKDF-SHA512 with AES-GCM-256                   1
# 360  2024-12-30  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 361  2025-01-01        HKDF-SHA256 with AES-GCM-128             1115309
# 362  2025-01-01        HKDF-SHA256 with AES-GCM-256                   1
# 363  2025-01-01  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 364  2025-01-01        HKDF-SHA384 with AES-GCM-128                   1
# 365  2025-01-01        HKDF-SHA384 with AES-GCM-256                   1
# 366  2025-01-01  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 367  2025-01-01        HKDF-SHA512 with AES-GCM-128                   1
# 368  2025-01-01        HKDF-SHA512 with AES-GCM-256                   1
# 369  2025-01-01  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 370  2025-01-02        HKDF-SHA256 with AES-GCM-128             1113996
# 371  2025-01-02        HKDF-SHA256 with AES-GCM-256                   1
# 372  2025-01-02  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 373  2025-01-02        HKDF-SHA384 with AES-GCM-128                   1
# 374  2025-01-02        HKDF-SHA384 with AES-GCM-256                   1
# 375  2025-01-02  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 376  2025-01-02        HKDF-SHA512 with AES-GCM-128                   1
# 377  2025-01-02        HKDF-SHA512 with AES-GCM-256                   1
# 378  2025-01-02  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 379  2025-01-03        HKDF-SHA256 with AES-GCM-128             1113771
# 380  2025-01-03        HKDF-SHA256 with AES-GCM-256                   1
# 381  2025-01-03  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 382  2025-01-03        HKDF-SHA384 with AES-GCM-128                   1
# 383  2025-01-03        HKDF-SHA384 with AES-GCM-256                   1
# 384  2025-01-03  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 385  2025-01-03        HKDF-SHA512 with AES-GCM-128                   1
# 386  2025-01-03        HKDF-SHA512 with AES-GCM-256                   1
# 387  2025-01-03  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 388  2025-01-04        HKDF-SHA256 with AES-GCM-128             1113569
# 389  2025-01-04        HKDF-SHA256 with AES-GCM-256                   1
# 390  2025-01-04  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 391  2025-01-04        HKDF-SHA384 with AES-GCM-128                   1
# 392  2025-01-04        HKDF-SHA384 with AES-GCM-256                   1
# 393  2025-01-04  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 394  2025-01-04        HKDF-SHA512 with AES-GCM-128                   1
# 395  2025-01-04        HKDF-SHA512 with AES-GCM-256                   1
# 396  2025-01-04  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 397  2025-01-05        HKDF-SHA256 with AES-GCM-128             1113447
# 398  2025-01-05        HKDF-SHA256 with AES-GCM-256                   1
# 399  2025-01-05  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 400  2025-01-05        HKDF-SHA384 with AES-GCM-128                   1
# 401  2025-01-05        HKDF-SHA384 with AES-GCM-256                   1
# 402  2025-01-05  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 403  2025-01-05        HKDF-SHA512 with AES-GCM-128                   1
# 404  2025-01-05        HKDF-SHA512 with AES-GCM-256                   1
# 405  2025-01-05  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 406  2025-01-06        HKDF-SHA256 with AES-GCM-128             1113353
# 407  2025-01-06        HKDF-SHA256 with AES-GCM-256                   1
# 408  2025-01-06  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 409  2025-01-06        HKDF-SHA384 with AES-GCM-128                   1
# 410  2025-01-06        HKDF-SHA384 with AES-GCM-256                   1
# 411  2025-01-06  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 412  2025-01-06        HKDF-SHA512 with AES-GCM-128                   1
# 413  2025-01-06        HKDF-SHA512 with AES-GCM-256                   1
# 414  2025-01-06  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 415  2025-01-07        HKDF-SHA256 with AES-GCM-128             1113094
# 416  2025-01-07        HKDF-SHA256 with AES-GCM-256                   1
# 417  2025-01-07  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 418  2025-01-07        HKDF-SHA384 with AES-GCM-128                   1
# 419  2025-01-07        HKDF-SHA384 with AES-GCM-256                   1
# 420  2025-01-07  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 421  2025-01-07        HKDF-SHA512 with AES-GCM-128                   1
# 422  2025-01-07        HKDF-SHA512 with AES-GCM-256                   1
# 423  2025-01-07  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 424  2025-01-08        HKDF-SHA256 with AES-GCM-128             1111916
# 425  2025-01-08        HKDF-SHA256 with AES-GCM-256                   1
# 426  2025-01-08  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 427  2025-01-08        HKDF-SHA384 with AES-GCM-128                   1
# 428  2025-01-08        HKDF-SHA384 with AES-GCM-256                   1
# 429  2025-01-08  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 430  2025-01-08        HKDF-SHA512 with AES-GCM-128                   1
# 431  2025-01-08        HKDF-SHA512 with AES-GCM-256                   1
# 432  2025-01-08  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 433  2025-01-09        HKDF-SHA256 with AES-GCM-128             1111376
# 434  2025-01-09        HKDF-SHA256 with AES-GCM-256                   1
# 435  2025-01-09  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 436  2025-01-09        HKDF-SHA384 with AES-GCM-128                   1
# 437  2025-01-09        HKDF-SHA384 with AES-GCM-256                   1
# 438  2025-01-09  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 439  2025-01-09        HKDF-SHA512 with AES-GCM-128                   1
# 440  2025-01-09        HKDF-SHA512 with AES-GCM-256                   1
# 441  2025-01-09  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 442  2025-01-10        HKDF-SHA256 with AES-GCM-128             1110914
# 443  2025-01-10        HKDF-SHA256 with AES-GCM-256                   1
# 444  2025-01-10  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 445  2025-01-10        HKDF-SHA384 with AES-GCM-128                   1
# 446  2025-01-10        HKDF-SHA384 with AES-GCM-256                   1
# 447  2025-01-10  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 448  2025-01-10        HKDF-SHA512 with AES-GCM-128                   1
# 449  2025-01-10        HKDF-SHA512 with AES-GCM-256                   1
# 450  2025-01-10  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 451  2025-01-11        HKDF-SHA256 with AES-GCM-128             1110893
# 452  2025-01-11        HKDF-SHA256 with AES-GCM-256                   1
# 453  2025-01-11  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 454  2025-01-11        HKDF-SHA384 with AES-GCM-128                   1
# 455  2025-01-11        HKDF-SHA384 with AES-GCM-256                   1
# 456  2025-01-11  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 457  2025-01-11        HKDF-SHA512 with AES-GCM-128                   1
# 458  2025-01-11        HKDF-SHA512 with AES-GCM-256                   1
# 459  2025-01-11  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 460  2025-01-12        HKDF-SHA256 with AES-GCM-128             1110535
# 461  2025-01-12        HKDF-SHA256 with AES-GCM-256                   1
# 462  2025-01-12  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 463  2025-01-12        HKDF-SHA384 with AES-GCM-128                   1
# 464  2025-01-12        HKDF-SHA384 with AES-GCM-256                   1
# 465  2025-01-12  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 466  2025-01-12        HKDF-SHA512 with AES-GCM-128                   1
# 467  2025-01-12        HKDF-SHA512 with AES-GCM-256                   1
# 468  2025-01-12  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 469  2025-01-13        HKDF-SHA256 with AES-GCM-128             1110165
# 470  2025-01-13        HKDF-SHA256 with AES-GCM-256                   1
# 471  2025-01-13  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 472  2025-01-13        HKDF-SHA384 with AES-GCM-128                   1
# 473  2025-01-13        HKDF-SHA384 with AES-GCM-256                   1
# 474  2025-01-13  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 475  2025-01-13        HKDF-SHA512 with AES-GCM-128                   1
# 476  2025-01-13        HKDF-SHA512 with AES-GCM-256                   1
# 477  2025-01-13  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 478  2025-01-14        HKDF-SHA256 with AES-GCM-128             1110316
# 479  2025-01-14        HKDF-SHA256 with AES-GCM-256                   1
# 480  2025-01-14  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 481  2025-01-14        HKDF-SHA384 with AES-GCM-128                   1
# 482  2025-01-14        HKDF-SHA384 with AES-GCM-256                   1
# 483  2025-01-14  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 484  2025-01-14        HKDF-SHA512 with AES-GCM-128                   1
# 485  2025-01-14        HKDF-SHA512 with AES-GCM-256                   1
# 486  2025-01-14  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 487  2025-01-15        HKDF-SHA256 with AES-GCM-128             1110343
# 488  2025-01-15        HKDF-SHA256 with AES-GCM-256                   1
# 489  2025-01-15  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 490  2025-01-15        HKDF-SHA384 with AES-GCM-128                   1
# 491  2025-01-15        HKDF-SHA384 with AES-GCM-256                   1
# 492  2025-01-15  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 493  2025-01-15        HKDF-SHA512 with AES-GCM-128                   1
# 494  2025-01-15        HKDF-SHA512 with AES-GCM-256                   1
# 495  2025-01-15  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 496  2025-01-16        HKDF-SHA256 with AES-GCM-128             1110196
# 497  2025-01-16        HKDF-SHA256 with AES-GCM-256                   1
# 498  2025-01-16  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 499  2025-01-16        HKDF-SHA384 with AES-GCM-128                   1
# 500  2025-01-16        HKDF-SHA384 with AES-GCM-256                   1
# 501  2025-01-16  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 502  2025-01-16        HKDF-SHA512 with AES-GCM-128                   1
# 503  2025-01-16        HKDF-SHA512 with AES-GCM-256                   1
# 504  2025-01-16  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 505  2025-01-17        HKDF-SHA256 with AES-GCM-128             1110018
# 506  2025-01-17        HKDF-SHA256 with AES-GCM-256                   1
# 507  2025-01-17  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 508  2025-01-17        HKDF-SHA384 with AES-GCM-128                   1
# 509  2025-01-17        HKDF-SHA384 with AES-GCM-256                   1
# 510  2025-01-17  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 511  2025-01-17        HKDF-SHA512 with AES-GCM-128                   1
# 512  2025-01-17        HKDF-SHA512 with AES-GCM-256                   1
# 513  2025-01-17  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 514  2025-01-18        HKDF-SHA256 with AES-GCM-128             1109383
# 515  2025-01-18        HKDF-SHA256 with AES-GCM-256                   1
# 516  2025-01-18  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 517  2025-01-18        HKDF-SHA384 with AES-GCM-128                   1
# 518  2025-01-18        HKDF-SHA384 with AES-GCM-256                   1
# 519  2025-01-18  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 520  2025-01-18        HKDF-SHA512 with AES-GCM-128                   1
# 521  2025-01-18        HKDF-SHA512 with AES-GCM-256                   1
# 522  2025-01-18  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 523  2025-01-19        HKDF-SHA256 with AES-GCM-128             1109187
# 524  2025-01-19        HKDF-SHA256 with AES-GCM-256                   1
# 525  2025-01-19  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 526  2025-01-19        HKDF-SHA384 with AES-GCM-128                   1
# 527  2025-01-19        HKDF-SHA384 with AES-GCM-256                   1
# 528  2025-01-19  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 529  2025-01-19        HKDF-SHA512 with AES-GCM-128                   1
# 530  2025-01-19        HKDF-SHA512 with AES-GCM-256                   1
# 531  2025-01-19  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 532  2025-01-20        HKDF-SHA256 with AES-GCM-128             1109118
# 533  2025-01-20        HKDF-SHA256 with AES-GCM-256                   1
# 534  2025-01-20  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 535  2025-01-20        HKDF-SHA384 with AES-GCM-128                   1
# 536  2025-01-20        HKDF-SHA384 with AES-GCM-256                   1
# 537  2025-01-20  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 538  2025-01-20        HKDF-SHA512 with AES-GCM-128                   1
# 539  2025-01-20        HKDF-SHA512 with AES-GCM-256                   1
# 540  2025-01-20  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 541  2025-01-21        HKDF-SHA256 with AES-GCM-128             1109455
# 542  2025-01-21        HKDF-SHA256 with AES-GCM-256                   1
# 543  2025-01-21  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 544  2025-01-21        HKDF-SHA384 with AES-GCM-128                   1
# 545  2025-01-21        HKDF-SHA384 with AES-GCM-256                   1
# 546  2025-01-21  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 547  2025-01-21        HKDF-SHA512 with AES-GCM-128                   1
# 548  2025-01-21        HKDF-SHA512 with AES-GCM-256                   1
# 549  2025-01-21  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 550  2025-01-22        HKDF-SHA256 with AES-GCM-128             1109871
# 551  2025-01-22        HKDF-SHA256 with AES-GCM-256                   1
# 552  2025-01-22  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 553  2025-01-22        HKDF-SHA384 with AES-GCM-128                   1
# 554  2025-01-22        HKDF-SHA384 with AES-GCM-256                   1
# 555  2025-01-22  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 556  2025-01-22        HKDF-SHA512 with AES-GCM-128                   1
# 557  2025-01-22        HKDF-SHA512 with AES-GCM-256                   1
# 558  2025-01-22  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 559  2025-01-23        HKDF-SHA256 with AES-GCM-128             1109817
# 560  2025-01-23        HKDF-SHA256 with AES-GCM-256                   1
# 561  2025-01-23  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 562  2025-01-23        HKDF-SHA384 with AES-GCM-128                   1
# 563  2025-01-23        HKDF-SHA384 with AES-GCM-256                   1
# 564  2025-01-23  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 565  2025-01-23        HKDF-SHA512 with AES-GCM-128                   1
# 566  2025-01-23        HKDF-SHA512 with AES-GCM-256                   1
# 567  2025-01-23  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 568  2025-01-24        HKDF-SHA256 with AES-GCM-128             1109310
# 569  2025-01-24        HKDF-SHA256 with AES-GCM-256                   1
# 570  2025-01-24  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 571  2025-01-24        HKDF-SHA384 with AES-GCM-128                   1
# 572  2025-01-24        HKDF-SHA384 with AES-GCM-256                   1
# 573  2025-01-24  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 574  2025-01-24        HKDF-SHA512 with AES-GCM-128                   1
# 575  2025-01-24        HKDF-SHA512 with AES-GCM-256                   1
# 576  2025-01-24  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 577  2025-01-25        HKDF-SHA256 with AES-GCM-128             1108868
# 578  2025-01-25        HKDF-SHA256 with AES-GCM-256                   1
# 579  2025-01-25  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 580  2025-01-25        HKDF-SHA384 with AES-GCM-128                   1
# 581  2025-01-25        HKDF-SHA384 with AES-GCM-256                   1
# 582  2025-01-25  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 583  2025-01-25        HKDF-SHA512 with AES-GCM-128                   1
# 584  2025-01-25        HKDF-SHA512 with AES-GCM-256                   1
# 585  2025-01-25  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 586  2025-01-26        HKDF-SHA256 with AES-GCM-128             1108554
# 587  2025-01-26        HKDF-SHA256 with AES-GCM-256                   1
# 588  2025-01-26  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 589  2025-01-26        HKDF-SHA384 with AES-GCM-128                   1
# 590  2025-01-26        HKDF-SHA384 with AES-GCM-256                   1
# 591  2025-01-26  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 592  2025-01-26        HKDF-SHA512 with AES-GCM-128                   1
# 593  2025-01-26        HKDF-SHA512 with AES-GCM-256                   1
# 594  2025-01-26  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 595  2025-01-27        HKDF-SHA256 with AES-GCM-128             1108497
# 596  2025-01-27        HKDF-SHA256 with AES-GCM-256                   1
# 597  2025-01-27  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 598  2025-01-27        HKDF-SHA384 with AES-GCM-128                   1
# 599  2025-01-27        HKDF-SHA384 with AES-GCM-256                   1
# 600  2025-01-27  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 601  2025-01-27        HKDF-SHA512 with AES-GCM-128                   1
# 602  2025-01-27        HKDF-SHA512 with AES-GCM-256                   1
# 603  2025-01-27  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 604  2025-01-28        HKDF-SHA256 with AES-GCM-128             1108527
# 605  2025-01-28        HKDF-SHA256 with AES-GCM-256                   1
# 606  2025-01-28  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 607  2025-01-28        HKDF-SHA384 with AES-GCM-128                   1
# 608  2025-01-28        HKDF-SHA384 with AES-GCM-256                   1
# 609  2025-01-28  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 610  2025-01-28        HKDF-SHA512 with AES-GCM-128                   1
# 611  2025-01-28        HKDF-SHA512 with AES-GCM-256                   1
# 612  2025-01-28  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 613  2025-01-29        HKDF-SHA256 with AES-GCM-128             1108630
# 614  2025-01-29        HKDF-SHA256 with AES-GCM-256                   1
# 615  2025-01-29  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 616  2025-01-29        HKDF-SHA384 with AES-GCM-128                   1
# 617  2025-01-29        HKDF-SHA384 with AES-GCM-256                   1
# 618  2025-01-29  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 619  2025-01-29        HKDF-SHA512 with AES-GCM-128                   1
# 620  2025-01-29        HKDF-SHA512 with AES-GCM-256                   1
# 621  2025-01-29  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 622  2025-01-30        HKDF-SHA256 with AES-GCM-128             1108620
# 623  2025-01-30        HKDF-SHA256 with AES-GCM-256                   1
# 624  2025-01-30  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 625  2025-01-30        HKDF-SHA384 with AES-GCM-128                   1
# 626  2025-01-30        HKDF-SHA384 with AES-GCM-256                   1
# 627  2025-01-30  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 628  2025-01-30        HKDF-SHA512 with AES-GCM-128                   1
# 629  2025-01-30        HKDF-SHA512 with AES-GCM-256                   1
# 630  2025-01-30  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 631  2025-01-31        HKDF-SHA256 with AES-GCM-128             1108569
# 632  2025-01-31        HKDF-SHA256 with AES-GCM-256                   1
# 633  2025-01-31  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 634  2025-01-31        HKDF-SHA384 with AES-GCM-128                   1
# 635  2025-01-31        HKDF-SHA384 with AES-GCM-256                   1
# 636  2025-01-31  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 637  2025-01-31        HKDF-SHA512 with AES-GCM-128                   1
# 638  2025-01-31        HKDF-SHA512 with AES-GCM-256                   1
# 639  2025-01-31  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 640  2025-02-01        HKDF-SHA256 with AES-GCM-128             1108605
# 641  2025-02-01        HKDF-SHA256 with AES-GCM-256                   1
# 642  2025-02-01  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 643  2025-02-01        HKDF-SHA384 with AES-GCM-128                   1
# 644  2025-02-01        HKDF-SHA384 with AES-GCM-256                   1
# 645  2025-02-01  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 646  2025-02-01        HKDF-SHA512 with AES-GCM-128                   1
# 647  2025-02-01        HKDF-SHA512 with AES-GCM-256                   1
# 648  2025-02-01  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 649  2025-02-02        HKDF-SHA256 with AES-GCM-128             1108088
# 650  2025-02-02        HKDF-SHA256 with AES-GCM-256                   1
# 651  2025-02-02  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 652  2025-02-02        HKDF-SHA384 with AES-GCM-128                   1
# 653  2025-02-02        HKDF-SHA384 with AES-GCM-256                   1
# 654  2025-02-02  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 655  2025-02-02        HKDF-SHA512 with AES-GCM-128                   1
# 656  2025-02-02        HKDF-SHA512 with AES-GCM-256                   1
# 657  2025-02-02  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 658  2025-02-03        HKDF-SHA256 with AES-GCM-128             1107846
# 659  2025-02-03        HKDF-SHA256 with AES-GCM-256                   1
# 660  2025-02-03  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 661  2025-02-03        HKDF-SHA384 with AES-GCM-128                   1
# 662  2025-02-03        HKDF-SHA384 with AES-GCM-256                   1
# 663  2025-02-03  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 664  2025-02-03        HKDF-SHA512 with AES-GCM-128                   1
# 665  2025-02-03        HKDF-SHA512 with AES-GCM-256                   1
# 666  2025-02-03  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 667  2025-02-04        HKDF-SHA256 with AES-GCM-128             1107894
# 668  2025-02-04        HKDF-SHA256 with AES-GCM-256                   1
# 669  2025-02-04  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 670  2025-02-04        HKDF-SHA384 with AES-GCM-128                   1
# 671  2025-02-04        HKDF-SHA384 with AES-GCM-256                   1
# 672  2025-02-04  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 673  2025-02-04        HKDF-SHA512 with AES-GCM-128                   1
# 674  2025-02-04        HKDF-SHA512 with AES-GCM-256                   1
# 675  2025-02-04  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 676  2025-02-05        HKDF-SHA256 with AES-GCM-128             1107798
# 677  2025-02-05        HKDF-SHA256 with AES-GCM-256                   1
# 678  2025-02-05  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 679  2025-02-05        HKDF-SHA384 with AES-GCM-128                   1
# 680  2025-02-05        HKDF-SHA384 with AES-GCM-256                   1
# 681  2025-02-05  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 682  2025-02-05        HKDF-SHA512 with AES-GCM-128                   1
# 683  2025-02-05        HKDF-SHA512 with AES-GCM-256                   1
# 684  2025-02-05  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 685  2025-02-06        HKDF-SHA256 with AES-GCM-128             1107700
# 686  2025-02-06        HKDF-SHA256 with AES-GCM-256                   1
# 687  2025-02-06  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 688  2025-02-06        HKDF-SHA384 with AES-GCM-128                   1
# 689  2025-02-06        HKDF-SHA384 with AES-GCM-256                   1
# 690  2025-02-06  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 691  2025-02-06        HKDF-SHA512 with AES-GCM-128                   1
# 692  2025-02-06        HKDF-SHA512 with AES-GCM-256                   1
# 693  2025-02-06  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 694  2025-02-07        HKDF-SHA256 with AES-GCM-128             1107526
# 695  2025-02-07        HKDF-SHA256 with AES-GCM-256                   1
# 696  2025-02-07  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 697  2025-02-07        HKDF-SHA384 with AES-GCM-128                   1
# 698  2025-02-07        HKDF-SHA384 with AES-GCM-256                   1
# 699  2025-02-07  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 700  2025-02-07        HKDF-SHA512 with AES-GCM-128                   1
# 701  2025-02-07        HKDF-SHA512 with AES-GCM-256                   1
# 702  2025-02-07  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 703  2025-02-08        HKDF-SHA256 with AES-GCM-128             1105892
# 704  2025-02-08        HKDF-SHA256 with AES-GCM-256                   1
# 705  2025-02-08  HKDF-SHA256 with ChaCha20-Poly1305                   2
# 706  2025-02-08        HKDF-SHA384 with AES-GCM-128                   1
# 707  2025-02-08        HKDF-SHA384 with AES-GCM-256                   1
# 708  2025-02-08  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 709  2025-02-08        HKDF-SHA512 with AES-GCM-128                   1
# 710  2025-02-08        HKDF-SHA512 with AES-GCM-256                   1
# 711  2025-02-08  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 712  2025-02-09        HKDF-SHA256 with AES-GCM-128             1106022
# 713  2025-02-09        HKDF-SHA256 with AES-GCM-256                   2
# 714  2025-02-09  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 715  2025-02-09        HKDF-SHA384 with AES-GCM-128                   1
# 716  2025-02-09        HKDF-SHA384 with AES-GCM-256                   1
# 717  2025-02-09  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 718  2025-02-09        HKDF-SHA512 with AES-GCM-128                   1
# 719  2025-02-09        HKDF-SHA512 with AES-GCM-256                   1
# 720  2025-02-09  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 721  2025-02-10        HKDF-SHA256 with AES-GCM-128             1106052
# 722  2025-02-10        HKDF-SHA256 with AES-GCM-256                   2
# 723  2025-02-10  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 724  2025-02-10        HKDF-SHA384 with AES-GCM-128                   1
# 725  2025-02-10        HKDF-SHA384 with AES-GCM-256                   1
# 726  2025-02-10  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 727  2025-02-10        HKDF-SHA512 with AES-GCM-128                   1
# 728  2025-02-10        HKDF-SHA512 with AES-GCM-256                   1
# 729  2025-02-10  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 730  2025-02-11        HKDF-SHA256 with AES-GCM-128             1106383
# 731  2025-02-11        HKDF-SHA256 with AES-GCM-256                   2
# 732  2025-02-11  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 733  2025-02-11        HKDF-SHA384 with AES-GCM-128                   1
# 734  2025-02-11        HKDF-SHA384 with AES-GCM-256                   1
# 735  2025-02-11  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 736  2025-02-11        HKDF-SHA512 with AES-GCM-128                   1
# 737  2025-02-11        HKDF-SHA512 with AES-GCM-256                   1
# 738  2025-02-11  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 739  2025-02-12        HKDF-SHA256 with AES-GCM-128             1106274
# 740  2025-02-12        HKDF-SHA256 with AES-GCM-256                   2
# 741  2025-02-12  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 742  2025-02-12        HKDF-SHA384 with AES-GCM-128                   1
# 743  2025-02-12        HKDF-SHA384 with AES-GCM-256                   1
# 744  2025-02-12  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 745  2025-02-12        HKDF-SHA512 with AES-GCM-128                   1
# 746  2025-02-12        HKDF-SHA512 with AES-GCM-256                   1
# 747  2025-02-12  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 748  2025-02-14        HKDF-SHA256 with AES-GCM-128             1106067
# 749  2025-02-14        HKDF-SHA256 with AES-GCM-256                   2
# 750  2025-02-14  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 751  2025-02-14        HKDF-SHA384 with AES-GCM-128                   1
# 752  2025-02-14        HKDF-SHA384 with AES-GCM-256                   1
# 753  2025-02-14  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 754  2025-02-14        HKDF-SHA512 with AES-GCM-128                   1
# 755  2025-02-14        HKDF-SHA512 with AES-GCM-256                   1
# 756  2025-02-14  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 757  2025-02-15        HKDF-SHA256 with AES-GCM-128             1106198
# 758  2025-02-15        HKDF-SHA256 with AES-GCM-256                   2
# 759  2025-02-15  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 760  2025-02-15        HKDF-SHA384 with AES-GCM-128                   1
# 761  2025-02-15        HKDF-SHA384 with AES-GCM-256                   1
# 762  2025-02-15  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 763  2025-02-15        HKDF-SHA512 with AES-GCM-128                   1
# 764  2025-02-15        HKDF-SHA512 with AES-GCM-256                   1
# 765  2025-02-15  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 766  2025-02-16        HKDF-SHA256 with AES-GCM-128             1105733
# 767  2025-02-16        HKDF-SHA256 with AES-GCM-256                   2
# 768  2025-02-16  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 769  2025-02-16        HKDF-SHA384 with AES-GCM-128                   1
# 770  2025-02-16        HKDF-SHA384 with AES-GCM-256                   1
# 771  2025-02-16  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 772  2025-02-16        HKDF-SHA512 with AES-GCM-128                   1
# 773  2025-02-16        HKDF-SHA512 with AES-GCM-256                   1
# 774  2025-02-16  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 775  2025-02-17        HKDF-SHA256 with AES-GCM-128             1105842
# 776  2025-02-17        HKDF-SHA256 with AES-GCM-256                   2
# 777  2025-02-17  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 778  2025-02-17        HKDF-SHA384 with AES-GCM-128                   1
# 779  2025-02-17        HKDF-SHA384 with AES-GCM-256                   1
# 780  2025-02-17  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 781  2025-02-17        HKDF-SHA512 with AES-GCM-128                   1
# 782  2025-02-17        HKDF-SHA512 with AES-GCM-256                   1
# 783  2025-02-17  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 784  2025-02-18        HKDF-SHA256 with AES-GCM-128             1106236
# 785  2025-02-18        HKDF-SHA256 with AES-GCM-256                   2
# 786  2025-02-18  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 787  2025-02-18        HKDF-SHA384 with AES-GCM-128                   1
# 788  2025-02-18        HKDF-SHA384 with AES-GCM-256                   1
# 789  2025-02-18  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 790  2025-02-18        HKDF-SHA512 with AES-GCM-128                   1
# 791  2025-02-18        HKDF-SHA512 with AES-GCM-256                   1
# 792  2025-02-18  HKDF-SHA512 with ChaCha20-Poly1305                   1
# 793  2025-02-19        HKDF-SHA256 with AES-GCM-128             1106666
# 794  2025-02-19        HKDF-SHA256 with AES-GCM-256                   2
# 795  2025-02-19  HKDF-SHA256 with ChaCha20-Poly1305                   3
# 796  2025-02-19        HKDF-SHA384 with AES-GCM-128                   1
# 797  2025-02-19        HKDF-SHA384 with AES-GCM-256                   1
# 798  2025-02-19  HKDF-SHA384 with ChaCha20-Poly1305                   1
# 799  2025-02-19        HKDF-SHA512 with AES-GCM-128                   1
# 800  2025-02-19        HKDF-SHA512 with AES-GCM-256                   1
# 801  2025-02-19  HKDF-SHA512 with ChaCha20-Poly1305                   1
# Data saved to ./pickle/2026-04-12_17H-03M-18S_ech_cipher-suites_by_test_dates.pickle

# %% [markdown]
# ALL CipherSuites even when they not exist:
#
# SELECT
#     ec.test_date,
#     hcs.cipher_suite,
#     COUNT(*) AS cipher_suite_count
# FROM
#     public."ECHCiphers" ec
# JOIN
#     public."HPKECipherSuites" hcs ON ec.ech_cipher_kdf_id = hcs.kdf_id AND ec.ech_cipher_aead_id = hcs.aead_id
# WHERE ec.test_date = %s
# GROUP BY
#     ec.test_date, hcs.cipher_suite
# ORDER BY
#     ec.test_date, hcs.cipher_suite;
